# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import yfinance as yf
import os
import datetime as dt

# %% [markdown]
# ## More simplistic and fantastic way to get data table inside Web HTML as dataframes

# %%
payload=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
constituents_table = payload[0]
df = constituents_table

# %% [markdown]
# ## Output Structure of Dataframe from web table

# %%
df.head(5)
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD              Abiomed     reports             Health Care
# 4    ACN            Accenture     reports  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# 3   815094         1981
# 4  1467373         1989

# %%
index_symbols = df['Symbol']
total_symbols = len(index_symbols)

# %% [markdown]
# ## Accumulate all ticker symbols to get Ticker Object from YF in one call

# %%
all_tickers = "";
for index, symbol in index_symbols.iteritems(): 
    new_symbol = symbol.replace(".","-")
    all_tickers += new_symbol + ' ';
print(all_tickers)
# Out:
# MMM ABT ABBV ABMD ACN ATVI ADBE AMD AAP AES AFL A APD AKAM ALK ALB ARE ALXN ALGN ALLE LNT ALL GOOGL GOOG MO AMZN AMCR AEE AAL AEP AXP AIG AMT AWK AMP ABC AME AMGN APH ADI ANSS ANTM AON AOS APA AAPL AMAT APTV ADM ANET AJG AIZ T ATO ADSK ADP AZO AVB AVY BKR BLL BAC BK BAX BDX BRK-B BBY BIO BIIB BLK BA BKNG BWA BXP BSX BMY AVGO BR BF-B CHRW COG CDNS CZR CPB COF CAH KMX CCL CARR CTLT CAT CBOE CBRE CDW CE CNC CNP CERN CF SCHW CHTR CVX CMG CB CHD CI CINF CTAS CSCO C CFG CTXS CLX CME CMS KO CTSH CL CMCSA CMA CAG COP ED STZ COO CPRT GLW CTVA COST CCI CSX CMI CVS DHI DHR DRI DVA DE DAL XRAY DVN DXCM FANG DLR DFS DISCA DISCK DISH DG DLTR D DPZ DOV DOW DTE DUK DRE DD DXC EMN ETN EBAY ECL EIX EW EA EMR ENPH ETR EOG EFX EQIX EQR ESS EL ETSY EVRG ES RE EXC EXPE EXPD EXR XOM FFIV FB FAST FRT FDX FIS FITB FE FRC FISV FLT FLIR FMC F FTNT FTV FBHS FOXA FOX BEN FCX GPS GRMN IT GNRC GD GE GIS GM GPC GILD GL GPN GS GWW HAL HBI HIG HAS HCA PEAK HSIC HSY HES HPE HLT HFC HOLX HD HON HRL HST HWM HPQ HUM HBAN HII IEX IDXX INFO ITW ILMN INCY IR INTC ICE IBM IP IPG IFF INTU ISRG IVZ IPGP IQV IRM JKHY J JBHT SJM JNJ JCI JPM JNPR KSU K KEY KEYS KMB KIM KMI KLAC KHC KR LB LHX LH LRCX LW LVS LEG LDOS LEN LLY LNC LIN LYV LKQ LMT L LOW LUMN LYB MTB MRO MPC MKTX MAR MMC MLM MAS MA MKC MXIM MCD MCK MDT MRK MET MTD MGM MCHP MU MSFT MAA MHK TAP MDLZ MPWR MNST MCO MS MOS MSI MSCI NDAQ NTAP NFLX NWL NEM NWSA NWS NEE NLSN NKE NI NSC NTRS NOC NLOK NCLH NOV NRG NUE NVDA NVR NXPI ORLY OXY ODFL OMC OKE ORCL OTIS PCAR PKG PH PAYX PAYC PYPL PENN PNR PBCT PEP PKI PRGO PFE PM PSX PNW PXD PNC POOL PPG PPL PFG PG PGR PLD PRU PEG PSA PHM PVH QRVO PWR QCOM DGX RL RJF RTX O REG REGN RF RSG RMD RHI ROK ROL ROP ROST RCL SPGI CRM SBAC SLB STX SEE SRE NOW SHW SPG SWKS SNA SO LUV SWK SBUX STT STE SYK SIVB SYF SNPS SYY TMUS TROW TTWO TPR TGT TEL TDY TFX TER TSLA TXN TXT TMO TJX TSCO TT TDG TRV TRMB TFC TWTR TYL TSN UDR ULTA USB UAA UA UNP UAL UNH UPS URI UHS UNM VLO VAR VTR VRSN VRSK VZ VRTX VFC VIAC VTRS V VNO VMC WRB WAB WMT WBA DIS WM WAT WEC WFC WELL WST WDC WU WRK WY WHR WMB WLTW WYNN XEL XLNX XYL YUM ZBRA ZBH ZION ZTS

# %%
all_tickers = 'MXIM'
stock_data = yf.Tickers(all_tickers)

# %% [markdown]
# ## Sample data read from ticker object

# %%
stock_data.tickers[0].history(period="1").head(1)
# Out:
#              Open   High    Low  Close   Volume  Dividends  Stock Splits
# Date
# 2021-03-24  90.05  91.46  89.38  89.39  1900802          0             0

# %%
symbols_data = []
sec_name_data = []
sector_data = []
industry_data = []
close_price_data = []
previous_close_price_data = []
floating_shares_data = []

# %% [markdown]
# ## Core logic to iterate all index constituents and get data points

# %% [markdown]
# ##### Note: Replace dot in ticker with hypen for yahoo finance api to work correctly

# %%
for index, symbol in index_symbols.iteritems(): 
    try:
        modified_symbol = symbol.replace('.','-')
        print('Processing stock#', index)
        stock_info = stock_data.tickers[index].info
        data = stock_data.tickers[index].history(period="1d")
        symbols_data.append(symbol);
        sec_name_data.append(df[df['Symbol'] == symbol]['Security'].values[0]);
        
        sector_data.append(df[df['Symbol'] == symbol]['GICS Sector'].values[0]);
        industry_data.append(df[df['Symbol'] == symbol]['GICS Sub-Industry'].values[0]);

        close_price_data.append(data.iloc[0]['Close'])

        if('previousClose' in stock_info):
            previous_close_price_data.append(stock_info['previousClose'])
        else:
            print('PREVIOUS CLOSE NOT FOUND FOR SYMBOL ', symbol)
            previous_close_price_data.append(None)

        if('floatShares' in stock_info):
            floating_shares_data.append(stock_info['floatShares'])
        else:
            print('FLOATING SHARES NOT FOUND FOR SYMBOL ', symbol)
            floating_shares_data.append(None)
    except:
        print('ERROR PROCESSING SYMBOL ', symbol)
# Out:
# Processing stock# 0
# Processing stock# 1
# ERROR PROCESSING SYMBOL  ABT
# Processing stock# 2
# ERROR PROCESSING SYMBOL  ABBV
# Processing stock# 3
# ERROR PROCESSING SYMBOL  ABMD
# Processing stock# 4
# ERROR PROCESSING SYMBOL  ACN
# Processing stock# 5
# ERROR PROCESSING SYMBOL  ATVI
# Processing stock# 6
# ERROR PROCESSING SYMBOL  ADBE
# Processing stock# 7
# ERROR PROCESSING SYMBOL  AMD
# Processing stock# 8
# ERROR PROCESSING SYMBOL  AAP
# Processing stock# 9
# ERROR PROCESSING SYMBOL  AES
# Processing stock# 10
# ERROR PROCESSING SYMBOL  AFL
# Processing stock# 11
# ERROR PROCESSING SYMBOL  A
# Processing stock# 12
# ERROR PROCESSING SYMBOL  APD
# Processing stock# 13
# ERROR PROCESSING SYMBOL  AKAM
# Processing stock# 14
# ERROR PROCESSING SYMBOL  ALK
# Processing stock# 15
# ERROR PROCESSING SYMBOL  ALB
# Processing stock# 16
# ERROR PROCESSING SYMBOL  ARE
# Processing stock# 17
# ERROR PROCESSING SYMBOL  ALXN
# Processing stock# 18
# ERROR PROCESSING SYMBOL  ALGN
# Processing stock# 19
# ERROR PROCESSING SYMBOL  ALLE
# Processing stock# 20
# ERROR PROCESSING SYMBOL  LNT
# Processing stock# 21
# ERROR PROCESSING SYMBOL  ALL
# Processing stock# 22
# ERROR PROCESSING SYMBOL  GOOGL
# Processing stock# 23
# ERROR PROCESSING SYMBOL  GOOG
# Processing stock# 24
# ERROR PROCESSING SYMBOL  MO
# Processing stock# 25
# ERROR PROCESSING SYMBOL  AMZN
# Processing stock# 26
# ERROR PROCESSING SYMBOL  AMCR
# Processing stock# 27
# ERROR PROCESSING SYMBOL  AEE
# Processing stock# 28
# ERROR PROCESSING SYMBOL  AAL
# Processing stock# 29
# ERROR PROCESSING SYMBOL  AEP
# Processing stock# 30
# ERROR PROCESSING SYMBOL  AXP
# Processing stock# 31
# ERROR PROCESSING SYMBOL  AIG
# Processing stock# 32
# ERROR PROCESSING SYMBOL  AMT
# Processing stock# 33
# ERROR PROCESSING SYMBOL  AWK
# Processing stock# 34
# ERROR PROCESSING SYMBOL  AMP
# Processing stock# 35
# ERROR PROCESSING SYMBOL  ABC
# Processing stock# 36
# ERROR PROCESSING SYMBOL  AME
# Processing stock# 37
# ERROR PROCESSING SYMBOL  AMGN
# Processing stock# 38
# ERROR PROCESSING SYMBOL  APH
# Processing stock# 39
# ERROR PROCESSING SYMBOL  ADI
# Processing stock# 40
# ERROR PROCESSING SYMBOL  ANSS
# Processing stock# 41
# ERROR PROCESSING SYMBOL  ANTM
# Processing stock# 42
# ERROR PROCESSING SYMBOL  AON
# Processing stock# 43
# ERROR PROCESSING SYMBOL  AOS
# Processing stock# 44
# ERROR PROCESSING SYMBOL  APA
# Processing stock# 45
# ERROR PROCESSING SYMBOL  AAPL
# Processing stock# 46
# ERROR PROCESSING SYMBOL  AMAT
# Processing stock# 47
# ERROR PROCESSING SYMBOL  APTV
# Processing stock# 48
# ERROR PROCESSING SYMBOL  ADM
# Processing stock# 49
# ERROR PROCESSING SYMBOL  ANET
# Processing stock# 50
# ERROR PROCESSING SYMBOL  AJG
# Processing stock# 51
# ERROR PROCESSING SYMBOL  AIZ
# Processing stock# 52
# ERROR PROCESSING SYMBOL  T
# Processing stock# 53
# ERROR PROCESSING SYMBOL  ATO
# Processing stock# 54
# ERROR PROCESSING SYMBOL  ADSK
# Processing stock# 55
# ERROR PROCESSING SYMBOL  ADP
# Processing stock# 56
# ERROR PROCESSING SYMBOL  AZO
# Processing stock# 57
# ERROR PROCESSING SYMBOL  AVB
# Processing stock# 58
# ERROR PROCESSING SYMBOL  AVY
# Processing stock# 59
# ERROR PROCESSING SYMBOL  BKR
# Processing stock# 60
# ERROR PROCESSING SYMBOL  BLL
# Processing stock# 61
# ERROR PROCESSING SYMBOL  BAC
# Processing stock# 62
# ERROR PROCESSING SYMBOL  BK
# Processing stock# 63
# ERROR PROCESSING SYMBOL  BAX
# Processing stock# 64
# ERROR PROCESSING SYMBOL  BDX
# Processing stock# 65
# ERROR PROCESSING SYMBOL  BRK.B
# Processing stock# 66
# ERROR PROCESSING SYMBOL  BBY
# Processing stock# 67
# ERROR PROCESSING SYMBOL  BIO
# Processing stock# 68
# ERROR PROCESSING SYMBOL  BIIB
# Processing stock# 69
# ERROR PROCESSING SYMBOL  BLK
# Processing stock# 70
# ERROR PROCESSING SYMBOL  BA
# Processing stock# 71
# ERROR PROCESSING SYMBOL  BKNG
# Processing stock# 72
# ERROR PROCESSING SYMBOL  BWA
# Processing stock# 73
# ERROR PROCESSING SYMBOL  BXP
# Processing stock# 74
# ERROR PROCESSING SYMBOL  BSX
# Processing stock# 75
# ERROR PROCESSING SYMBOL  BMY
# Processing stock# 76
# ERROR PROCESSING SYMBOL  AVGO
# Processing stock# 77
# ERROR PROCESSING SYMBOL  BR
# Processing stock# 78
# ERROR PROCESSING SYMBOL  BF.B
# Processing stock# 79
# ERROR PROCESSING SYMBOL  CHRW
# Processing stock# 80
# ERROR PROCESSING SYMBOL  COG
# Processing stock# 81
# ERROR PROCESSING SYMBOL  CDNS
# Processing stock# 82
# ERROR PROCESSING SYMBOL  CZR
# Processing stock# 83
# ERROR PROCESSING SYMBOL  CPB
# Processing stock# 84
# ERROR PROCESSING SYMBOL  COF
# Processing stock# 85
# ERROR PROCESSING SYMBOL  CAH
# Processing stock# 86
# ERROR PROCESSING SYMBOL  KMX
# Processing stock# 87
# ERROR PROCESSING SYMBOL  CCL
# Processing stock# 88
# ERROR PROCESSING SYMBOL  CARR
# Processing stock# 89
# ERROR PROCESSING SYMBOL  CTLT
# Processing stock# 90
# ERROR PROCESSING SYMBOL  CAT
# Processing stock# 91
# ERROR PROCESSING SYMBOL  CBOE
# Processing stock# 92
# ERROR PROCESSING SYMBOL  CBRE
# Processing stock# 93
# ERROR PROCESSING SYMBOL  CDW
# Processing stock# 94
# ERROR PROCESSING SYMBOL  CE
# Processing stock# 95
# ERROR PROCESSING SYMBOL  CNC
# Processing stock# 96
# ERROR PROCESSING SYMBOL  CNP
# Processing stock# 97
# ERROR PROCESSING SYMBOL  CERN
# Processing stock# 98
# ERROR PROCESSING SYMBOL  CF
# Processing stock# 99
# ERROR PROCESSING SYMBOL  SCHW
# Processing stock# 100
# ERROR PROCESSING SYMBOL  CHTR
# Processing stock# 101
# ERROR PROCESSING SYMBOL  CVX
# Processing stock# 102
# ERROR PROCESSING SYMBOL  CMG
# Processing stock# 103
# ERROR PROCESSING SYMBOL  CB
# Processing stock# 104
# ERROR PROCESSING SYMBOL  CHD
# Processing stock# 105
# ERROR PROCESSING SYMBOL  CI
# Processing stock# 106
# ERROR PROCESSING SYMBOL  CINF
# Processing stock# 107
# ERROR PROCESSING SYMBOL  CTAS
# Processing stock# 108
# ERROR PROCESSING SYMBOL  CSCO
# Processing stock# 109
# ERROR PROCESSING SYMBOL  C
# Processing stock# 110
# ERROR PROCESSING SYMBOL  CFG
# Processing stock# 111
# ERROR PROCESSING SYMBOL  CTXS
# Processing stock# 112
# ERROR PROCESSING SYMBOL  CLX
# Processing stock# 113
# ERROR PROCESSING SYMBOL  CME
# Processing stock# 114
# ERROR PROCESSING SYMBOL  CMS
# Processing stock# 115
# ERROR PROCESSING SYMBOL  KO
# Processing stock# 116
# ERROR PROCESSING SYMBOL  CTSH
# Processing stock# 117
# ERROR PROCESSING SYMBOL  CL
# Processing stock# 118
# ERROR PROCESSING SYMBOL  CMCSA
# Processing stock# 119
# ERROR PROCESSING SYMBOL  CMA
# Processing stock# 120
# ERROR PROCESSING SYMBOL  CAG
# Processing stock# 121
# ERROR PROCESSING SYMBOL  COP
# Processing stock# 122
# ERROR PROCESSING SYMBOL  ED
# Processing stock# 123
# ERROR PROCESSING SYMBOL  STZ
# Processing stock# 124
# ERROR PROCESSING SYMBOL  COO
# Processing stock# 125
# ERROR PROCESSING SYMBOL  CPRT
# Processing stock# 126
# ERROR PROCESSING SYMBOL  GLW
# Processing stock# 127
# ERROR PROCESSING SYMBOL  CTVA
# Processing stock# 128
# ERROR PROCESSING SYMBOL  COST
# Processing stock# 129
# ERROR PROCESSING SYMBOL  CCI
# Processing stock# 130
# ERROR PROCESSING SYMBOL  CSX
# Processing stock# 131
# ERROR PROCESSING SYMBOL  CMI
# Processing stock# 132
# ERROR PROCESSING SYMBOL  CVS
# Processing stock# 133
# ERROR PROCESSING SYMBOL  DHI
# Processing stock# 134
# ERROR PROCESSING SYMBOL  DHR
# Processing stock# 135
# ERROR PROCESSING SYMBOL  DRI
# Processing stock# 136
# ERROR PROCESSING SYMBOL  DVA
# Processing stock# 137
# ERROR PROCESSING SYMBOL  DE
# Processing stock# 138
# ERROR PROCESSING SYMBOL  DAL
# Processing stock# 139
# ERROR PROCESSING SYMBOL  XRAY
# Processing stock# 140
# ERROR PROCESSING SYMBOL  DVN
# Processing stock# 141
# ERROR PROCESSING SYMBOL  DXCM
# Processing stock# 142
# ERROR PROCESSING SYMBOL  FANG
# Processing stock# 143
# ERROR PROCESSING SYMBOL  DLR
# Processing stock# 144
# ERROR PROCESSING SYMBOL  DFS
# Processing stock# 145
# ERROR PROCESSING SYMBOL  DISCA
# Processing stock# 146
# ERROR PROCESSING SYMBOL  DISCK
# Processing stock# 147
# ERROR PROCESSING SYMBOL  DISH
# Processing stock# 148
# ERROR PROCESSING SYMBOL  DG
# Processing stock# 149
# ERROR PROCESSING SYMBOL  DLTR
# Processing stock# 150
# ERROR PROCESSING SYMBOL  D
# Processing stock# 151
# ERROR PROCESSING SYMBOL  DPZ
# Processing stock# 152
# ERROR PROCESSING SYMBOL  DOV
# Processing stock# 153
# ERROR PROCESSING SYMBOL  DOW
# Processing stock# 154
# ERROR PROCESSING SYMBOL  DTE
# Processing stock# 155
# ERROR PROCESSING SYMBOL  DUK
# Processing stock# 156
# ERROR PROCESSING SYMBOL  DRE
# Processing stock# 157
# ERROR PROCESSING SYMBOL  DD
# Processing stock# 158
# ERROR PROCESSING SYMBOL  DXC
# Processing stock# 159
# ERROR PROCESSING SYMBOL  EMN
# Processing stock# 160
# ERROR PROCESSING SYMBOL  ETN
# Processing stock# 161
# ERROR PROCESSING SYMBOL  EBAY
# Processing stock# 162
# ERROR PROCESSING SYMBOL  ECL
# Processing stock# 163
# ERROR PROCESSING SYMBOL  EIX
# Processing stock# 164
# ERROR PROCESSING SYMBOL  EW
# Processing stock# 165
# ERROR PROCESSING SYMBOL  EA
# Processing stock# 166
# ERROR PROCESSING SYMBOL  EMR
# Processing stock# 167
# ERROR PROCESSING SYMBOL  ENPH
# Processing stock# 168
# ERROR PROCESSING SYMBOL  ETR
# Processing stock# 169
# ERROR PROCESSING SYMBOL  EOG
# Processing stock# 170
# ERROR PROCESSING SYMBOL  EFX
# Processing stock# 171
# ERROR PROCESSING SYMBOL  EQIX
# Processing stock# 172
# ERROR PROCESSING SYMBOL  EQR
# Processing stock# 173
# ERROR PROCESSING SYMBOL  ESS
# Processing stock# 174
# ERROR PROCESSING SYMBOL  EL
# Processing stock# 175
# ERROR PROCESSING SYMBOL  ETSY
# Processing stock# 176
# ERROR PROCESSING SYMBOL  EVRG
# Processing stock# 177
# ERROR PROCESSING SYMBOL  ES
# Processing stock# 178
# ERROR PROCESSING SYMBOL  RE
# Processing stock# 179
# ERROR PROCESSING SYMBOL  EXC
# Processing stock# 180
# ERROR PROCESSING SYMBOL  EXPE
# Processing stock# 181
# ERROR PROCESSING SYMBOL  EXPD
# Processing stock# 182
# ERROR PROCESSING SYMBOL  EXR
# Processing stock# 183
# ERROR PROCESSING SYMBOL  XOM
# Processing stock# 184
# ERROR PROCESSING SYMBOL  FFIV
# Processing stock# 185
# ERROR PROCESSING SYMBOL  FB
# Processing stock# 186
# ERROR PROCESSING SYMBOL  FAST
# Processing stock# 187
# ERROR PROCESSING SYMBOL  FRT
# Processing stock# 188
# ERROR PROCESSING SYMBOL  FDX
# Processing stock# 189
# ERROR PROCESSING SYMBOL  FIS
# Processing stock# 190
# ERROR PROCESSING SYMBOL  FITB
# Processing stock# 191
# ERROR PROCESSING SYMBOL  FE
# Processing stock# 192
# ERROR PROCESSING SYMBOL  FRC
# Processing stock# 193
# ERROR PROCESSING SYMBOL  FISV
# Processing stock# 194
# ERROR PROCESSING SYMBOL  FLT
# Processing stock# 195
# ERROR PROCESSING SYMBOL  FLIR
# Processing stock# 196
# ERROR PROCESSING SYMBOL  FMC
# Processing stock# 197
# ERROR PROCESSING SYMBOL  F
# Processing stock# 198
# ERROR PROCESSING SYMBOL  FTNT
# Processing stock# 199
# ERROR PROCESSING SYMBOL  FTV
# Processing stock# 200
# ERROR PROCESSING SYMBOL  FBHS
# Processing stock# 201
# ERROR PROCESSING SYMBOL  FOXA
# Processing stock# 202
# ERROR PROCESSING SYMBOL  FOX
# Processing stock# 203
# ERROR PROCESSING SYMBOL  BEN
# Processing stock# 204
# ERROR PROCESSING SYMBOL  FCX
# Processing stock# 205
# ERROR PROCESSING SYMBOL  GPS
# Processing stock# 206
# ERROR PROCESSING SYMBOL  GRMN
# Processing stock# 207
# ERROR PROCESSING SYMBOL  IT
# Processing stock# 208
# ERROR PROCESSING SYMBOL  GNRC
# Processing stock# 209
# ERROR PROCESSING SYMBOL  GD
# Processing stock# 210
# ERROR PROCESSING SYMBOL  GE
# Processing stock# 211
# ERROR PROCESSING SYMBOL  GIS
# Processing stock# 212
# ERROR PROCESSING SYMBOL  GM
# Processing stock# 213
# ERROR PROCESSING SYMBOL  GPC
# Processing stock# 214
# ERROR PROCESSING SYMBOL  GILD
# Processing stock# 215
# ERROR PROCESSING SYMBOL  GL
# Processing stock# 216
# ERROR PROCESSING SYMBOL  GPN
# Processing stock# 217
# ERROR PROCESSING SYMBOL  GS
# Processing stock# 218
# ERROR PROCESSING SYMBOL  GWW
# Processing stock# 219
# ERROR PROCESSING SYMBOL  HAL
# Processing stock# 220
# ERROR PROCESSING SYMBOL  HBI
# Processing stock# 221
# ERROR PROCESSING SYMBOL  HIG
# Processing stock# 222
# ERROR PROCESSING SYMBOL  HAS
# Processing stock# 223
# ERROR PROCESSING SYMBOL  HCA
# Processing stock# 224
# ERROR PROCESSING SYMBOL  PEAK
# Processing stock# 225
# ERROR PROCESSING SYMBOL  HSIC
# Processing stock# 226
# ERROR PROCESSING SYMBOL  HSY
# Processing stock# 227
# ERROR PROCESSING SYMBOL  HES
# Processing stock# 228
# ERROR PROCESSING SYMBOL  HPE
# Processing stock# 229
# ERROR PROCESSING SYMBOL  HLT
# Processing stock# 230
# ERROR PROCESSING SYMBOL  HFC
# Processing stock# 231
# ERROR PROCESSING SYMBOL  HOLX
# Processing stock# 232
# ERROR PROCESSING SYMBOL  HD
# Processing stock# 233
# ERROR PROCESSING SYMBOL  HON
# Processing stock# 234
# ERROR PROCESSING SYMBOL  HRL
# Processing stock# 235
# ERROR PROCESSING SYMBOL  HST
# Processing stock# 236
# ERROR PROCESSING SYMBOL  HWM
# Processing stock# 237
# ERROR PROCESSING SYMBOL  HPQ
# Processing stock# 238
# ERROR PROCESSING SYMBOL  HUM
# Processing stock# 239
# ERROR PROCESSING SYMBOL  HBAN
# Processing stock# 240
# ERROR PROCESSING SYMBOL  HII
# Processing stock# 241
# ERROR PROCESSING SYMBOL  IEX
# Processing stock# 242
# ERROR PROCESSING SYMBOL  IDXX
# Processing stock# 243
# ERROR PROCESSING SYMBOL  INFO
# Processing stock# 244
# ERROR PROCESSING SYMBOL  ITW
# Processing stock# 245
# ERROR PROCESSING SYMBOL  ILMN
# Processing stock# 246
# ERROR PROCESSING SYMBOL  INCY
# Processing stock# 247
# ERROR PROCESSING SYMBOL  IR
# Processing stock# 248
# ERROR PROCESSING SYMBOL  INTC
# Processing stock# 249
# ERROR PROCESSING SYMBOL  ICE
# Processing stock# 250
# ERROR PROCESSING SYMBOL  IBM
# Processing stock# 251
# ERROR PROCESSING SYMBOL  IP
# Processing stock# 252
# ERROR PROCESSING SYMBOL  IPG
# Processing stock# 253
# ERROR PROCESSING SYMBOL  IFF
# Processing stock# 254
# ERROR PROCESSING SYMBOL  INTU
# Processing stock# 255
# ERROR PROCESSING SYMBOL  ISRG
# Processing stock# 256
# ERROR PROCESSING SYMBOL  IVZ
# Processing stock# 257
# ERROR PROCESSING SYMBOL  IPGP
# Processing stock# 258
# ERROR PROCESSING SYMBOL  IQV
# Processing stock# 259
# ERROR PROCESSING SYMBOL  IRM
# Processing stock# 260
# ERROR PROCESSING SYMBOL  JKHY
# Processing stock# 261
# ERROR PROCESSING SYMBOL  J
# Processing stock# 262
# ERROR PROCESSING SYMBOL  JBHT
# Processing stock# 263
# ERROR PROCESSING SYMBOL  SJM
# Processing stock# 264
# ERROR PROCESSING SYMBOL  JNJ
# Processing stock# 265
# ERROR PROCESSING SYMBOL  JCI
# Processing stock# 266
# ERROR PROCESSING SYMBOL  JPM
# Processing stock# 267
# ERROR PROCESSING SYMBOL  JNPR
# Processing stock# 268
# ERROR PROCESSING SYMBOL  KSU
# Processing stock# 269
# ERROR PROCESSING SYMBOL  K
# Processing stock# 270
# ERROR PROCESSING SYMBOL  KEY
# Processing stock# 271
# ERROR PROCESSING SYMBOL  KEYS
# Processing stock# 272
# ERROR PROCESSING SYMBOL  KMB
# Processing stock# 273
# ERROR PROCESSING SYMBOL  KIM
# Processing stock# 274
# ERROR PROCESSING SYMBOL  KMI
# Processing stock# 275
# ERROR PROCESSING SYMBOL  KLAC
# Processing stock# 276
# ERROR PROCESSING SYMBOL  KHC
# Processing stock# 277
# ERROR PROCESSING SYMBOL  KR
# Processing stock# 278
# ERROR PROCESSING SYMBOL  LB
# Processing stock# 279
# ERROR PROCESSING SYMBOL  LHX
# Processing stock# 280
# ERROR PROCESSING SYMBOL  LH
# Processing stock# 281
# ERROR PROCESSING SYMBOL  LRCX
# Processing stock# 282
# ERROR PROCESSING SYMBOL  LW
# Processing stock# 283
# ERROR PROCESSING SYMBOL  LVS
# Processing stock# 284
# ERROR PROCESSING SYMBOL  LEG
# Processing stock# 285
# ERROR PROCESSING SYMBOL  LDOS
# Processing stock# 286
# ERROR PROCESSING SYMBOL  LEN
# Processing stock# 287
# ERROR PROCESSING SYMBOL  LLY
# Processing stock# 288
# ERROR PROCESSING SYMBOL  LNC
# Processing stock# 289
# ERROR PROCESSING SYMBOL  LIN
# Processing stock# 290
# ERROR PROCESSING SYMBOL  LYV
# Processing stock# 291
# ERROR PROCESSING SYMBOL  LKQ
# Processing stock# 292
# ERROR PROCESSING SYMBOL  LMT
# Processing stock# 293
# ERROR PROCESSING SYMBOL  L
# Processing stock# 294
# ERROR PROCESSING SYMBOL  LOW
# Processing stock# 295
# ERROR PROCESSING SYMBOL  LUMN
# Processing stock# 296
# ERROR PROCESSING SYMBOL  LYB
# Processing stock# 297
# ERROR PROCESSING SYMBOL  MTB
# Processing stock# 298
# ERROR PROCESSING SYMBOL  MRO
# Processing stock# 299
# ERROR PROCESSING SYMBOL  MPC
# Processing stock# 300
# ERROR PROCESSING SYMBOL  MKTX
# Processing stock# 301
# ERROR PROCESSING SYMBOL  MAR
# Processing stock# 302
# ERROR PROCESSING SYMBOL  MMC
# Processing stock# 303
# ERROR PROCESSING SYMBOL  MLM
# Processing stock# 304
# ERROR PROCESSING SYMBOL  MAS
# Processing stock# 305
# ERROR PROCESSING SYMBOL  MA
# Processing stock# 306
# ERROR PROCESSING SYMBOL  MKC
# Processing stock# 307
# ERROR PROCESSING SYMBOL  MXIM
# Processing stock# 308
# ERROR PROCESSING SYMBOL  MCD
# Processing stock# 309
# ERROR PROCESSING SYMBOL  MCK
# Processing stock# 310
# ERROR PROCESSING SYMBOL  MDT
# Processing stock# 311
# ERROR PROCESSING SYMBOL  MRK
# Processing stock# 312
# ERROR PROCESSING SYMBOL  MET
# Processing stock# 313
# ERROR PROCESSING SYMBOL  MTD
# Processing stock# 314
# ERROR PROCESSING SYMBOL  MGM
# Processing stock# 315
# ERROR PROCESSING SYMBOL  MCHP
# Processing stock# 316
# ERROR PROCESSING SYMBOL  MU
# Processing stock# 317
# ERROR PROCESSING SYMBOL  MSFT
# Processing stock# 318
# ERROR PROCESSING SYMBOL  MAA
# Processing stock# 319
# ERROR PROCESSING SYMBOL  MHK
# Processing stock# 320
# ERROR PROCESSING SYMBOL  TAP
# Processing stock# 321
# ERROR PROCESSING SYMBOL  MDLZ
# Processing stock# 322
# ERROR PROCESSING SYMBOL  MPWR
# Processing stock# 323
# ERROR PROCESSING SYMBOL  MNST
# Processing stock# 324
# ERROR PROCESSING SYMBOL  MCO
# Processing stock# 325
# ERROR PROCESSING SYMBOL  MS
# Processing stock# 326
# ERROR PROCESSING SYMBOL  MOS
# Processing stock# 327
# ERROR PROCESSING SYMBOL  MSI
# Processing stock# 328
# ERROR PROCESSING SYMBOL  MSCI
# Processing stock# 329
# ERROR PROCESSING SYMBOL  NDAQ
# Processing stock# 330
# ERROR PROCESSING SYMBOL  NTAP
# Processing stock# 331
# ERROR PROCESSING SYMBOL  NFLX
# Processing stock# 332
# ERROR PROCESSING SYMBOL  NWL
# Processing stock# 333
# ERROR PROCESSING SYMBOL  NEM
# Processing stock# 334
# ERROR PROCESSING SYMBOL  NWSA
# Processing stock# 335
# ERROR PROCESSING SYMBOL  NWS
# Processing stock# 336
# ERROR PROCESSING SYMBOL  NEE
# Processing stock# 337
# ERROR PROCESSING SYMBOL  NLSN
# Processing stock# 338
# ERROR PROCESSING SYMBOL  NKE
# Processing stock# 339
# ERROR PROCESSING SYMBOL  NI
# Processing stock# 340
# ERROR PROCESSING SYMBOL  NSC
# Processing stock# 341
# ERROR PROCESSING SYMBOL  NTRS
# Processing stock# 342
# ERROR PROCESSING SYMBOL  NOC
# Processing stock# 343
# ERROR PROCESSING SYMBOL  NLOK
# Processing stock# 344
# ERROR PROCESSING SYMBOL  NCLH
# Processing stock# 345
# ERROR PROCESSING SYMBOL  NOV
# Processing stock# 346
# ERROR PROCESSING SYMBOL  NRG
# Processing stock# 347
# ERROR PROCESSING SYMBOL  NUE
# Processing stock# 348
# ERROR PROCESSING SYMBOL  NVDA
# Processing stock# 349
# ERROR PROCESSING SYMBOL  NVR
# Processing stock# 350
# ERROR PROCESSING SYMBOL  NXPI
# Processing stock# 351
# ERROR PROCESSING SYMBOL  ORLY
# Processing stock# 352
# ERROR PROCESSING SYMBOL  OXY
# Processing stock# 353
# ERROR PROCESSING SYMBOL  ODFL
# Processing stock# 354
# ERROR PROCESSING SYMBOL  OMC
# Processing stock# 355
# ERROR PROCESSING SYMBOL  OKE
# Processing stock# 356
# ERROR PROCESSING SYMBOL  ORCL
# Processing stock# 357
# ERROR PROCESSING SYMBOL  OTIS
# Processing stock# 358
# ERROR PROCESSING SYMBOL  PCAR
# Processing stock# 359
# ERROR PROCESSING SYMBOL  PKG
# Processing stock# 360
# ERROR PROCESSING SYMBOL  PH
# Processing stock# 361
# ERROR PROCESSING SYMBOL  PAYX
# Processing stock# 362
# ERROR PROCESSING SYMBOL  PAYC
# Processing stock# 363
# ERROR PROCESSING SYMBOL  PYPL
# Processing stock# 364
# ERROR PROCESSING SYMBOL  PENN
# Processing stock# 365
# ERROR PROCESSING SYMBOL  PNR
# Processing stock# 366
# ERROR PROCESSING SYMBOL  PBCT
# Processing stock# 367
# ERROR PROCESSING SYMBOL  PEP
# Processing stock# 368
# ERROR PROCESSING SYMBOL  PKI
# Processing stock# 369
# ERROR PROCESSING SYMBOL  PRGO
# Processing stock# 370
# ERROR PROCESSING SYMBOL  PFE
# Processing stock# 371
# ERROR PROCESSING SYMBOL  PM
# Processing stock# 372
# ERROR PROCESSING SYMBOL  PSX
# Processing stock# 373
# ERROR PROCESSING SYMBOL  PNW
# Processing stock# 374
# ERROR PROCESSING SYMBOL  PXD
# Processing stock# 375
# ERROR PROCESSING SYMBOL  PNC
# Processing stock# 376
# ERROR PROCESSING SYMBOL  POOL
# Processing stock# 377
# ERROR PROCESSING SYMBOL  PPG
# Processing stock# 378
# ERROR PROCESSING SYMBOL  PPL
# Processing stock# 379
# ERROR PROCESSING SYMBOL  PFG
# Processing stock# 380
# ERROR PROCESSING SYMBOL  PG
# Processing stock# 381
# ERROR PROCESSING SYMBOL  PGR
# Processing stock# 382
# ERROR PROCESSING SYMBOL  PLD
# Processing stock# 383
# ERROR PROCESSING SYMBOL  PRU
# Processing stock# 384
# ERROR PROCESSING SYMBOL  PEG
# Processing stock# 385
# ERROR PROCESSING SYMBOL  PSA
# Processing stock# 386
# ERROR PROCESSING SYMBOL  PHM
# Processing stock# 387
# ERROR PROCESSING SYMBOL  PVH
# Processing stock# 388
# ERROR PROCESSING SYMBOL  QRVO
# Processing stock# 389
# ERROR PROCESSING SYMBOL  PWR
# Processing stock# 390
# ERROR PROCESSING SYMBOL  QCOM
# Processing stock# 391
# ERROR PROCESSING SYMBOL  DGX
# Processing stock# 392
# ERROR PROCESSING SYMBOL  RL
# Processing stock# 393
# ERROR PROCESSING SYMBOL  RJF
# Processing stock# 394
# ERROR PROCESSING SYMBOL  RTX
# Processing stock# 395
# ERROR PROCESSING SYMBOL  O
# Processing stock# 396
# ERROR PROCESSING SYMBOL  REG
# Processing stock# 397
# ERROR PROCESSING SYMBOL  REGN
# Processing stock# 398
# ERROR PROCESSING SYMBOL  RF
# Processing stock# 399
# ERROR PROCESSING SYMBOL  RSG
# Processing stock# 400
# ERROR PROCESSING SYMBOL  RMD
# Processing stock# 401
# ERROR PROCESSING SYMBOL  RHI
# Processing stock# 402
# ERROR PROCESSING SYMBOL  ROK
# Processing stock# 403
# ERROR PROCESSING SYMBOL  ROL
# Processing stock# 404
# ERROR PROCESSING SYMBOL  ROP
# Processing stock# 405
# ERROR PROCESSING SYMBOL  ROST
# Processing stock# 406
# ERROR PROCESSING SYMBOL  RCL
# Processing stock# 407
# ERROR PROCESSING SYMBOL  SPGI
# Processing stock# 408
# ERROR PROCESSING SYMBOL  CRM
# Processing stock# 409
# ERROR PROCESSING SYMBOL  SBAC
# Processing stock# 410
# ERROR PROCESSING SYMBOL  SLB
# Processing stock# 411
# ERROR PROCESSING SYMBOL  STX
# Processing stock# 412
# ERROR PROCESSING SYMBOL  SEE
# Processing stock# 413
# ERROR PROCESSING SYMBOL  SRE
# Processing stock# 414
# ERROR PROCESSING SYMBOL  NOW
# Processing stock# 415
# ERROR PROCESSING SYMBOL  SHW
# Processing stock# 416
# ERROR PROCESSING SYMBOL  SPG
# Processing stock# 417
# ERROR PROCESSING SYMBOL  SWKS
# Processing stock# 418
# ERROR PROCESSING SYMBOL  SNA
# Processing stock# 419
# ERROR PROCESSING SYMBOL  SO
# Processing stock# 420
# ERROR PROCESSING SYMBOL  LUV
# Processing stock# 421
# ERROR PROCESSING SYMBOL  SWK
# Processing stock# 422
# ERROR PROCESSING SYMBOL  SBUX
# Processing stock# 423
# ERROR PROCESSING SYMBOL  STT
# Processing stock# 424
# ERROR PROCESSING SYMBOL  STE
# Processing stock# 425
# ERROR PROCESSING SYMBOL  SYK
# Processing stock# 426
# ERROR PROCESSING SYMBOL  SIVB
# Processing stock# 427
# ERROR PROCESSING SYMBOL  SYF
# Processing stock# 428
# ERROR PROCESSING SYMBOL  SNPS
# Processing stock# 429
# ERROR PROCESSING SYMBOL  SYY
# Processing stock# 430
# ERROR PROCESSING SYMBOL  TMUS
# Processing stock# 431
# ERROR PROCESSING SYMBOL  TROW
# Processing stock# 432
# ERROR PROCESSING SYMBOL  TTWO
# Processing stock# 433
# ERROR PROCESSING SYMBOL  TPR
# Processing stock# 434
# ERROR PROCESSING SYMBOL  TGT
# Processing stock# 435
# ERROR PROCESSING SYMBOL  TEL
# Processing stock# 436
# ERROR PROCESSING SYMBOL  TDY
# Processing stock# 437
# ERROR PROCESSING SYMBOL  TFX
# Processing stock# 438
# ERROR PROCESSING SYMBOL  TER
# Processing stock# 439
# ERROR PROCESSING SYMBOL  TSLA
# Processing stock# 440
# ERROR PROCESSING SYMBOL  TXN
# Processing stock# 441
# ERROR PROCESSING SYMBOL  TXT
# Processing stock# 442
# ERROR PROCESSING SYMBOL  TMO
# Processing stock# 443
# ERROR PROCESSING SYMBOL  TJX
# Processing stock# 444
# ERROR PROCESSING SYMBOL  TSCO
# Processing stock# 445
# ERROR PROCESSING SYMBOL  TT
# Processing stock# 446
# ERROR PROCESSING SYMBOL  TDG
# Processing stock# 447
# ERROR PROCESSING SYMBOL  TRV
# Processing stock# 448
# ERROR PROCESSING SYMBOL  TRMB
# Processing stock# 449
# ERROR PROCESSING SYMBOL  TFC
# Processing stock# 450
# ERROR PROCESSING SYMBOL  TWTR
# Processing stock# 451
# ERROR PROCESSING SYMBOL  TYL
# Processing stock# 452
# ERROR PROCESSING SYMBOL  TSN
# Processing stock# 453
# ERROR PROCESSING SYMBOL  UDR
# Processing stock# 454
# ERROR PROCESSING SYMBOL  ULTA
# Processing stock# 455
# ERROR PROCESSING SYMBOL  USB
# Processing stock# 456
# ERROR PROCESSING SYMBOL  UAA
# Processing stock# 457
# ERROR PROCESSING SYMBOL  UA
# Processing stock# 458
# ERROR PROCESSING SYMBOL  UNP
# Processing stock# 459
# ERROR PROCESSING SYMBOL  UAL
# Processing stock# 460
# ERROR PROCESSING SYMBOL  UNH
# Processing stock# 461
# ERROR PROCESSING SYMBOL  UPS
# Processing stock# 462
# ERROR PROCESSING SYMBOL  URI
# Processing stock# 463
# ERROR PROCESSING SYMBOL  UHS
# Processing stock# 464
# ERROR PROCESSING SYMBOL  UNM
# Processing stock# 465
# ERROR PROCESSING SYMBOL  VLO
# Processing stock# 466
# ERROR PROCESSING SYMBOL  VAR
# Processing stock# 467
# ERROR PROCESSING SYMBOL  VTR
# Processing stock# 468
# ERROR PROCESSING SYMBOL  VRSN
# Processing stock# 469
# ERROR PROCESSING SYMBOL  VRSK
# Processing stock# 470
# ERROR PROCESSING SYMBOL  VZ
# Processing stock# 471
# ERROR PROCESSING SYMBOL  VRTX
# Processing stock# 472
# ERROR PROCESSING SYMBOL  VFC
# Processing stock# 473
# ERROR PROCESSING SYMBOL  VIAC
# Processing stock# 474
# ERROR PROCESSING SYMBOL  VTRS
# Processing stock# 475
# ERROR PROCESSING SYMBOL  V
# Processing stock# 476
# ERROR PROCESSING SYMBOL  VNO
# Processing stock# 477
# ERROR PROCESSING SYMBOL  VMC
# Processing stock# 478
# ERROR PROCESSING SYMBOL  WRB
# Processing stock# 479
# ERROR PROCESSING SYMBOL  WAB
# Processing stock# 480
# ERROR PROCESSING SYMBOL  WMT
# Processing stock# 481
# ERROR PROCESSING SYMBOL  WBA
# Processing stock# 482
# ERROR PROCESSING SYMBOL  DIS
# Processing stock# 483
# ERROR PROCESSING SYMBOL  WM
# Processing stock# 484
# ERROR PROCESSING SYMBOL  WAT
# Processing stock# 485
# ERROR PROCESSING SYMBOL  WEC
# Processing stock# 486
# ERROR PROCESSING SYMBOL  WFC
# Processing stock# 487
# ERROR PROCESSING SYMBOL  WELL
# Processing stock# 488
# ERROR PROCESSING SYMBOL  WST
# Processing stock# 489
# ERROR PROCESSING SYMBOL  WDC
# Processing stock# 490
# ERROR PROCESSING SYMBOL  WU
# Processing stock# 491
# ERROR PROCESSING SYMBOL  WRK
# Processing stock# 492
# ERROR PROCESSING SYMBOL  WY
# Processing stock# 493
# ERROR PROCESSING SYMBOL  WHR
# Processing stock# 494
# ERROR PROCESSING SYMBOL  WMB
# Processing stock# 495
# ERROR PROCESSING SYMBOL  WLTW
# Processing stock# 496
# ERROR PROCESSING SYMBOL  WYNN
# Processing stock# 497
# ERROR PROCESSING SYMBOL  XEL
# Processing stock# 498
# ERROR PROCESSING SYMBOL  XLNX
# Processing stock# 499
# ERROR PROCESSING SYMBOL  XYL
# Processing stock# 500
# ERROR PROCESSING SYMBOL  YUM
# Processing stock# 501
# ERROR PROCESSING SYMBOL  ZBRA
# Processing stock# 502
# ERROR PROCESSING SYMBOL  ZBH
# Processing stock# 503
# ERROR PROCESSING SYMBOL  ZION
# Processing stock# 504
# ERROR PROCESSING SYMBOL  ZTS

# %% [markdown]
# ### Populate all collected data into dataframe - TODO: Need to find a better way to do it

# %%
out_data = {'Symbol': symbols_data,
            'Security': sec_name_data,
            'Sector': sector_data,
            'Industry': industry_data,
            'Close_Price': close_price_data,
            'Previous_Day_Close_Price': previous_close_price_data, 
            'Floating_Shares': floating_shares_data}
output_df = pd.DataFrame(out_data, columns= ['Symbol', 'Security', 'Sector', 'Industry','Close_Price','Previous_Day_Close_Price', 'Floating_Shares'])

# %% [markdown]
# ## Sample Output Data

# %%
output_df.head(100)
# Out:
#   Symbol    Security       Sector                  Industry  Close_Price  \
# 0    MMM  3M Company  Industrials  Industrial Conglomerates        89.39
#
#    Previous_Day_Close_Price  Floating_Shares
# 0                     88.85        266170140

# %% [markdown]
# ## Writing output data to excel file for further analysis

# %%
output_dir = '../results/sp500'
if not os.path.exists(output_dir):
    os.mkdir(output_dir);
    
today_date = dt.datetime.today().strftime('%Y-%m-%d')
output_file = 'performance_analysis_'+today_date+'.xlsx';

file_path = os.path.join(output_dir, output_file)

if os.path.exists(file_path):
    os.remove(file_path)

output_df.to_excel(file_path)
